# %% [markdown]
# ejemplos de Clase

# %%
lista_nombres = ["Elens", "Ariana", "Nieves"]

# %%
print(type(lista_nombres))
# Out:
# <class 'list'>

# %%
d = {1:2, 2:3}

# %%
print(type(d))
# Out:
# <class 'dict'>

# %%
class Mascota:
    pass

# %%
# características (atributos) de nuestra clase de mascota -> tipo, peso, edad

# %%
# método constructor

class Mascota:

    def __init__(self, tipo, nombre, peso, edad):
        self.tipo = tipo
        self.nombre = nombre
        self.peso = peso
        self.edad = edad

# %%
Jiraya = Mascota("felino", "Jiraya", 2.0, 1.5)

# %%
Jiraya.__dict__
# Out:
# {'tipo': 'felino', 'nombre': 'Jiraya', 'peso': 2.0, 'edad': 1.5}

# %%
print(Jiraya)

# %%
Mascota_mirian = Mascota("can","Freya", 11, 2)

# %%
class Mascota:

    def __init__(self, tipo, nombre, peso, edad):
        self.tipo = tipo
        self.nombre = nombre
        self.peso = peso
        self.edad = edad
    def hablar(self): # ahora, aquí dentro de la clase, esto SÍ es un método
        print(f"mi mascota {self.nombre} va a hablar")
        if self.tipo.lover() == "perro":
            print("Guau!!")
            elif self.tipo.lower() == "Gato"
            print("Miau!")
            else 
            print(f"Yo no se como hablan esos bichejos")
# Out:
#   Cell In[17], line 12
#     elif self.tipo.lower() == "Gato"
#     ^
# SyntaxError: invalid syntax

# %%
Mascota_mirian.hablar()
# Out:
# mi mascota Freya va a hablar

# %%
Jiraya.hablar()
# Out:
# mi mascota Jiraya va a hablar
