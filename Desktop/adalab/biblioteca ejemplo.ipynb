# %%
class Biblio:
    def __init__(self, nombre, lugar):
        self.nombre = nombre
        self.lugar = lugar
        self.libros = [] #
        def info(self):
            print(f"la librería" {self.nombre})

            def info:
                print(f"la librería {nombre} a la biblioteca" )
            def añadir_libro(self, nombre, autor)
