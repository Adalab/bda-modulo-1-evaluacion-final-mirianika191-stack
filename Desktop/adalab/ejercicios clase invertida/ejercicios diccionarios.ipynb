# %% [markdown]
# Ejercicios de diccionarios

# %% [markdown]
# Definir diccionarios
#
# Crea el diccionario festivos con las fechas como claves y los nombres como valores: 01/01: Año Nuevo, 06/01: Epifanía del Señor, 15/04: Viernes Santo, 15/08: Asunción de la Virgen, 12/10: Fiesta Nacional de España, 01/11: Todos los Santos, 06/12: Día de la Constitución Española, y 08/12: Inmaculada Concepción.

# %%
diccionari_festivos = {"01/01": "año nuevo", "06/01": "epifania del señor", "15/04": "viernes santo", "15/08": "asuncion de la virgen", "12/10": "fiesta nacional de españa", "01/11": "todos los santos", "06/12": "dia de la constitución española", "08/12": "inmaculada concepcion"}
print(diccionari_festivos)
# Out:
# {'01/01': 'año nuevo', '06/01': 'epifania del señor', '15/04': 'viernes santo', '15/08': 'asuncion de la virgen', '12/10': 'fiesta nacional de españa', '01/11': 'todos los santos', '06/12': 'dia de la constitución española', '08/12': 'inmaculada concepcion'}

# %% [markdown]
# Crea el diccionario monarcas con los países como claves y los nombres como valores: Bélgica: Philippe, Dinamarca: Margrethe II, Holanda: Beatrix, Noruega: Harald V, España: Felipe VI, Reino Unido: Carlos III.

# %%
monarcas_europeos = {"belgica": "philippe", "dinamarca": "margrethe II", "holanda": "beatrix", "noruega": "harald V", "españa": "felipe VI", "reino unido": "carlos III"}
print(monarcas_europeos)
# Out:
# {'belgica': 'philippe', 'dinamarca': 'margrethe II', 'holanda': 'beatrix', 'noruega': 'harald V', 'españa': 'felipe VI', 'reino unido': 'carlos III'}

# %% [markdown]
# Leer, añadir, y cambiar elementos
#
# ¿Qué festivo hay el 15/04?
#
# La reina 'Beatrix' abdicó, ahora es el rey 'Willem-Alexander'. Actualiza el dict.
#
# El rey de Luxemburgo se llama Henri. Añadelo al dict usando .update().

# %%
festivo_15_04 = diccionari_festivos["15/04"]

print(f"el festivo para la fecha 15/04 es:{festivo_15_04}")
# Out:
# el festivo para la fecha 15/04 es:viernes santo

# %%
monarcas_europeos["holanda"] = "willem-alexander"
print(monarcas_europeos)
# Out:
# {'belgica': 'philippe', 'dinamarca': 'margrethe II', 'holanda': 'willem-alexander', 'noruega': 'harald V', 'españa': 'felipe VI', 'reino unido': 'carlos III'}

# %%
monarcas_europeos.update({"luxemburgo":"henry"})
print(monarcas_europeos)
# Out:
# {'belgica': 'philippe', 'dinamarca': 'margrethe II', 'holanda': 'willem-alexander', 'noruega': 'harald V', 'españa': 'felipe VI', 'reino unido': 'carlos III', 'luxemburgo': 'henry'}

# %% [markdown]
# Comprobar contenidos
#
# ¿Cuántos países están definidos en monarcas?
#
# ¿Es 'Monaco' uno de ellos?
#
# ¿Es verdad que nos olvidamos de poner 'Suecia'? Compruébalo de una manera en que obtengas un True o False.

# %%
len(monarcas_europeos)
# Out:
# 7

# %%
buscar_pais = "monaco"
monaco_pais_incluido =

# %% [markdown]
# Copiar dicts, y borrar elementos
#
# Copia monarcas a monarcas2010.
#
# Quita España de monarcas2010.
#
# Quita el último elemento de monarcas2010.

# %% [markdown]
# Vaciar y borrar dicts
#
# Vacia el dict monarcas2010.

# %% [markdown]
# Obtener valores
#
# ¿Qué festivo hay el 06/01?
#
# Obten el festivo que haya el 08/03, y en su defecto devuélve 'Día Internacional de la Mujer'.
#
# Obten el festivo que haya el 31/11, y si no existe crea un par de clave-valor nuevo con el valor de 'Todos los Santos'.
