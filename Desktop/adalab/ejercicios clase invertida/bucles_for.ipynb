# %% [markdown]
# Usando la siguiente lista:
#
#
# Copy
# temperaturas = [2,45,67,23, 45,66,12,1,34,67,99,98,67,64, 44, 100]
# Crea tres listas nuevas, donde:
#
# En la primera tengamos temperaturas entre 0 - 10, llama a la nueva lista bajas_temp.
#
# En la segunda tengamos temperaturas entre 11- 20, llama a la nueva lista medias_temp.
#
# En la tercera tengamos temperaturas por encima de 20, llama a la nueva lista altas_temp

# %%
temperaturas = [2, 45, 67, 23, 45, 66, 12, 1, 34, 67, 99, 98, 67, 64, 44, 100]
print(temperaturas)
bajas_temp = [temperaturas for temperaturas in temperaturas if 0 <= temperaturas <= 10]
print(bajas_temp)
medias_temp = [temperaturas for temperaturas in temperaturas if 11 <= temperaturas <= 20]
print(medias_temp)
altas_temp = [temperaturas for temperaturas in temperaturas if temperaturas >20]
print(altas_temp)
# Out:
# [2, 45, 67, 23, 45, 66, 12, 1, 34, 67, 99, 98, 67, 64, 44, 100]
# [2, 1]
# [12]
# [45, 67, 23, 45, 66, 34, 67, 99, 98, 67, 64, 44, 100]

# %% [markdown]
# Las temperaturas están grados centígrados. Para cada una de las listas creadas en el ejercicio anterior, convertid las temperaturas a grados fahrenheit
#
#
# Copy
# # la relacion de grados celsius y fahrenheit es:
# (0 °C × 9 / 5) + 32 = 32 °F

# %%
bajas_temp_celsius = [2, 1]
medias_temp_celsius = [12]
altas_temp_celsius = [45, 67, 23, 45, 66, 34, 67, 99, 98, 67, 64, 44, 100]
def celsisus_a_fahrenheir(celsius):
    """convierte una temperatura de celsius a fahrenheit."""
    return (celsius * 9/5) +32
    bajas_tem_fahrenheit = [celsius_a_fahrenheit (c) for c in bajas_temp_celcsius]
    medias_temp_fahrenheit = [celsius_a_fahrenheit(c) for c in medias_temp_celsius]
    altas_temp_fahrenheit = [celsius_a_fahrenheit(c) for c in altas_temp_celsius]
print("---")
# 1. Bajas Temperaturas
bajas_temp_fahrenheit = [celsius_a_fahrenheit(c) for c in bajas_temp_celsius]

# 2. Medias Temperaturas
medias_temp_fahrenheit = [celsius_a_fahrenheit(c) for c in medias_temp_celsius]

# 3. Altas Temperaturas
altas_temp_fahrenheit = [celsius_a_fahrenheit(c) for c in altas_temp_celsius]

print("---")
print("1. Bajas Temperaturas:")
print(f"Celsius: {bajas_temp_celsius}")
print(f"Fahrenheit: {bajas_temp_fahrenheit}")
print("---")
print("2. Medias Temperaturas:")
print(f"Celsius: {medias_temp_celsius}")
print(f"Fahrenheit: {medias_temp_fahrenheit}")
print("---")
print("3. Altas Temperaturas:")
print(f"Celsius: {altas_temp_celsius}")
print(f"Fahrenheit: {altas_temp_fahrenheit}")
print("---")
# Out:
# ---
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 12
#      10 print("---")
#      11 # 1. Bajas Temperaturas
# ---> 12 bajas_temp_fahrenheit = [celsius_a_fahrenheit(c) for c in bajas_temp_celsius]
#      14 # 2. Medias Temperaturas
#      15 medias_temp_fahrenheit = [celsius_a_fahrenheit(c) for c in medias_temp_celsius]
#
# NameError: name 'celsius_a_fahrenheit' is not defined

# %% [markdown]
# Define e imprime un rango de 0 a 6 (excluido).

# %% [markdown]
# Define e imprime un rango de 5 a 9 ambos excluidos

# %% [markdown]
# Define e imprime un rango de 3 números que empiece en 2.

# %% [markdown]
# Define e imprime un rango que empiece en 2, aumentando cada paso por 3, que pare antes de llegar al número 13.

# %% [markdown]
# Define e imprime un rango con todos los valores impares que hay hasta 10.

# %% [markdown]
# Crea una lista nueva donde tengamos los números de la lista temperaturas elevados al cuadrado.

# %% [markdown]
# Crea una lista nueva donde tengamos el resto de la división de cada uno de los números entre 2.

# %% [markdown]
# Crea una lista nueva donde tengamos solo los elementos pares de la lista temperaturas.

# %% [markdown]
# Crea una lista nueva donde tengamos solo los elementos pares de la lista temperaturas.

# %% [markdown]
# Crea una lista nueva donde tengamos solo los elementos que sean menores que 50.

# %% [markdown]
# Crea una lista donde tengamos los valores "par" e "impar" en función de los valores de la lista original. La lista resultante tiene que ser como la que indicamos a continuación:
#
#
# Copy
# lista_strings = ["par","impar","impar","impar", "impar","par","par","impar","par","impar","impar","par","impar","par", "par", "par"]

# %% [markdown]
# Pide al usuario un número entero positivo y suma los números pares e impares por separado hasta ese número.

# %% [markdown]
# Pide al usuario ingresar una cadena y cuenta cuántas veces aparece cada vocal (a, e, i, o, u) en la cadena.
